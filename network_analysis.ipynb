# %% [markdown]
# # Network analysis of BiciMAD

# %%
import pandas as pd
import plotly.express as px
import json
import numpy as np
from scipy import stats
import networkx as nx
import plotly.graph_objects as go
from pyvis.network import Network
from geopy.distance import geodesic
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook
plt.rcParams["figure.figsize"] = [10, 5]

# %%
stations = pd.read_csv('data/bases_bicimad.csv', sep=';', index_col=False)
stations.drop(stations.loc[stations['Número'].isin(['001 b',
                                                    '020 ampliacion',
                                                    '025 b',
                                                    '080 b',
                                                    '090 ampliacion',
                                                    '106 b',
                                                    '111 b',
                                                    '116 b',
                                                    '128 ampliacion',
                                                    '140 ampliación',
                                                    '161 ampliacion',
                                                    ])].index, inplace=True)
#stations['Número'].iloc[0] = 1
stations['Número'] = stations['Número'].replace({'001 a': 1,
                                                 '025 a': 25,
                                                 '080 a': 80,
                                                 '106 a': 106,
                                                 '111 a': 111,
                                                 '116 a': 116
                                                 })
stations['Número'] = pd.to_numeric(stations['Número'])


def distance_calc (row):
    start = (40.4166, -3.70384)
    stop = (row['Latitud'], row['Longitud'])

    return geodesic(start, stop).meters

stations['dist_km0'] = stations.apply (lambda row: distance_calc(row), axis=1)

stations
# Out:
#      Número      Gis_X       Gis_Y  Fecha de Alta             Distrito  \
# 0         1  440443,61  4474290,65          43803           01  CENTRO
# 2         2  440134,83  4474678,23          41813           01  CENTRO
# 3         3  440012,98  4475760,68          41813         07  CHAMBERÍ
# 4         4   440396,4  4475565,36          41813           01  CENTRO
# 5         5  440447,06   4475539,6          41813           01  CENTRO
# ..      ...        ...         ...            ...                  ...
# 264     257  438063,25  4476718,06          44194  09  MONCLOA-ARAVACA
# 265     258  438326,14  4477849,84          44194  09  MONCLOA-ARAVACA
# 266     259  438344,78  4477338,89          44194  09  MONCLOA-ARAVACA
# 267     260  438328,53  4477762,41          44194  09  MONCLOA-ARAVACA
# 268     261  438161,53  4478015,95          44194  09  MONCLOA-ARAVACA
#
#                          Barrio                                  Calle  \
# 0                     01-06 SOL                      ALCALA, CALLE, DE
# 2             01-05 UNIVERSIDAD                 MIGUEL MOYA, CALLE, DE
# 3                07-02 ARAPILES  CONDE DEL VALLE DE SUCHIL, PLAZA, DEL
# 4             01-05 UNIVERSIDAD            MANUELA MALASAÑA, CALLE, DE
# 5                01-04 JUSTICIA                  FUENCARRAL, CALLE, DE
# ..                          ...                                    ...
# 264  09-03 CIUDAD UNIVERSITARIA           JUAN DE HERRERA, AVENIDA, DE
# 265  09-03 CIUDAD UNIVERSITARIA                   COMPLUTENSE, AVENIDA
# 266  09-03 CIUDAD UNIVERSITARIA               RAMON Y CAJAL, PLAZA, DE
# 267  09-03 CIUDAD UNIVERSITARIA         JOSE ANTONIO NOVAIS, CALLE, DE
# 268  09-03 CIUDAD UNIVERSITARIA                   COMPLUTENSE, AVENIDA
#
#          Nº Finca Tipo de Reserva  Número de Plazas  Longitud    Latitud  \
# 0               2         BiciMAD                30 -3.701998  40.417111
# 2               1         BiciMAD                24 -3.705674  40.420580
# 3               2         BiciMAD                18 -3.707212  40.430322
# 4               3         BiciMAD                24 -3.702674  40.428590
# 5             106         BiciMAD                27 -3.702074  40.428362
# ..            ...             ...               ...       ...        ...
# 264             1         BiciMAD                24 -3.730290  40.438804
# 265  frente al 14         BiciMAD                24 -3.727300  40.449019
# 266           S/N         BiciMAD                24 -3.727031  40.444418
# 267           S/N         BiciMAD                24 -3.727264  40.448232
# 268   frente al 7         BiciMAD                24 -3.729258  40.450503
#
#                                     Direccion     dist_km0
# 0                        ALCALA, CALLE, DE, 2   166.302566
# 2                   MIGUEL MOYA, CALLE, DE, 1   468.555831
# 3    CONDE DEL VALLE DE SUCHIL, PLAZA, DEL, 2  1550.414033
# 4              MANUELA MALASAÑA, CALLE, DE, 3  1335.130869
# 5                  FUENCARRAL, CALLE, DE, 106  1314.652786
# ..                                        ...          ...
# 264           JUAN DE HERRERA, AVENIDA, DE, 1  3334.216323
# 265        COMPLUTENSE, AVENIDA, frente al 14  4113.642283
# 266             RAMON Y CAJAL, PLAZA, DE, S/N  3662.530936
# 267       JOSE ANTONIO NOVAIS, CALLE, DE, S/N  4035.819273
# 268         COMPLUTENSE, AVENIDA, frente al 7  4338.719630
#
# [258 rows x 14 columns]

# %%
trips = pd.read_json('data/201906_Usage_Bicimad.json', lines=True,
                     encoding='latin-1', convert_dates='unplug_hourTime').query(
    'user_type in [1, 2]')[['idunplug_station', 'idplug_station',
                            'travel_time', 'ageRange', 'unplug_hourTime',
                            'zip_code', 'user_type']]

trips['zip_code'] = pd.to_numeric(trips['zip_code'], errors='coerce')
trips['unplug_hourTime'] = pd.to_datetime(trips['unplug_hourTime'].apply(lambda x: x['$date']))
trips = trips[trips['travel_time'] < 60*60*8]
trips['od_time_ratio'] = trips['travel_time'] / \
    trips.groupby(['idunplug_station', 'idplug_station'])[
    'travel_time'].transform('mean')
trips['o_time_ratio'] = trips['travel_time'] / \
    trips.groupby(['idunplug_station'])[
    'travel_time'].transform('mean')
trips['d_time_ratio'] = trips['travel_time'] / \
    trips.groupby(['idplug_station'])[
    'travel_time'].transform('mean')
trips['hour'] = trips['unplug_hourTime'].dt.hour
trips['day_type'] = trips['unplug_hourTime'].dt.weekday.isin([5, 6]).astype(int)
trips = trips.merge(stations[['Número', 'dist_km0']], how='left',
              left_on='idunplug_station', right_on='Número').rename(columns={'dist_km0': 'o_dist_km0'}).drop(columns='Número')
trips = trips.merge(stations[['Número', 'dist_km0']], how='left',
              left_on='idplug_station', right_on='Número').rename(columns={'dist_km0': 'd_dist_km0'}).drop(columns='Número')
trips = trips.fillna(trips.mean())

trips
# Out:
# <ipython-input-22-81e3bbcd28b2>:25: FutureWarning:
#
# DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#         idunplug_station  idplug_station  travel_time  ageRange  \
# 0                     90              66          219         0
# 1                     71             136          359         4
# 2                     39              38          375         4
# 3                     66              90          264         5
# 4                    152             166          367         4
# ...                  ...             ...          ...       ...
# 424492                55              71          471         0
# 424493                51             135          317         5
# 424494               172             174         1558         0
# 424495                35               2         2199         0
# 424496                30             130          301         5
#
#                  unplug_hourTime      zip_code  user_type  od_time_ratio  \
# 0      2019-06-01 00:00:00+02:00  94845.066194          1       0.243454
# 1      2019-06-01 00:00:00+02:00  28039.000000          1       0.493381
# 2      2019-06-01 00:00:00+02:00  28013.000000          1       1.232202
# 3      2019-06-01 00:00:00+02:00  28009.000000          1       0.772850
# 4      2019-06-01 00:00:00+02:00  28006.000000          1       0.779009
# ...                          ...           ...        ...            ...
# 424492 2019-06-26 23:00:00+02:00  94845.066194          1       0.635430
# 424493 2019-06-26 23:00:00+02:00  28045.000000          1       0.715425
# 424494 2019-06-26 23:00:00+02:00  94845.066194          1       0.903014
# 424495 2019-06-26 23:00:00+02:00  94845.066194          1       2.230676
# 424496 2019-06-26 23:00:00+02:00  28010.000000          1       0.275247
#
#         o_time_ratio  d_time_ratio  hour  day_type   o_dist_km0   d_dist_km0
# 0           0.253708      0.254429     0         1  1949.659347  1971.364279
# 1           0.406542      0.346933     0         1  2531.689730  3371.451753
# 2           0.407593      0.396823     0         1   736.833314   873.752025
# 3           0.270303      0.297862     0         1  1969.964110  1949.659347
# 4           0.390789      0.384688     0         1  4031.870979   858.577165
# ...              ...           ...   ...       ...          ...          ...
# 424492      0.514104      0.501796    23         0   845.361722  2531.689730
# 424493      0.356829      0.259280    23         0  1314.521569  2915.287342
# 424494      1.395094      1.545086    23         0  1953.275690  2140.986664
# 424495      2.027131      2.112135    23         0   615.794745   468.555831
# 424496      0.375194      0.406174    23         0   720.867121  2795.207693
#
# [424497 rows x 14 columns]

# %%
trips_grouped_count = trips.groupby(['idunplug_station', 'idplug_station']).agg(
    weight=('travel_time', 'count'), cost=('travel_time', 'mean')).reset_index()

# %%
trips_grouped_count['cost'] = trips_grouped_count['cost'].astype('int64')

# %%
trips_grouped_count[['weight', 'cost']].describe()
# Out:
#              weight          cost
# count  28965.000000  28965.000000
# mean      14.655515   1059.893112
# std       17.390449    739.444925
# min        1.000000     95.000000
# 25%        4.000000    682.000000
# 50%        9.000000    928.000000
# 75%       19.000000   1239.000000
# max      306.000000  21011.000000

# %%
od_df_count = trips.pivot_table(index='idunplug_station',
                                columns='idplug_station',
                                values='travel_time',
                                aggfunc=len,
                                fill_value=0)

# %%
px.histogram(trips_grouped_count['weight'], marginal='box')
# Out:
# <div>                            <div id="edc83037-d3f6-4ab3-a5e6-3c1f08a26d8a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("edc83037-d3f6-4ab3-a5e6-3c1f08a26d8a")) {                    Plotly.newPlot(                        "edc83037-d3f6-4ab3-a5e6-3c1f08a26d8a",                        [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "variable=weight<br>value=%{x}<br>count=%{y}<extra></extra>", "legendgroup":
31, 8, 29, 4, 11, 8, 17, 2, 22, 15, 13, 5, 7, 4, 45, 11, 3, 5, 10, 5, 5, 10, 5, 4, 10, 7, 3, 2, 11, 1, 1, 14, 11, 17, 14, 1, 2, 16, 5, 16, 4, 9, 7, 9, 11, 4, 4, 23, 4, 5, 13, 18, 19, 25, 1, 6, 17, 1, 3, 2, 3, 1, 8, 13, 2, 3, 8, 22, 13, 22, 3, 8, 5, 5, 1, 2, 2, 7, 14, 7, 1, 7, 4, 1, 4, 4, 11, 4, 9, 16, 26, 46, 12, 27, 20, 12, 3, 6, 34, 4, 5, 10, 23, 12, 23, 9, 6, 8, 25, 12, 16, 20, 12, 13, 13, 10, 25, 24, 1, 5, 44, 3, 2, 8, 27, 5, 19, 16, 30, 11, 4, 69, 56, 25, 32, 57, 30, 17, 2, 6, 12, 15, 5, 19, 1, 5, 24, 4, 2, 2, 10, 3, 5, 6, 18, 3, 4, 15, 15, 2, 28, 34, 7, 22, 14, 2, 4, 11, 5, 7, 19, 18, 19, 58, 13, 16, 5, 16, 5, 9, 6, 10, 6, 2, 4, 3, 1, 5, 10, 11, 20, 2, 11, 6, 9, 2, 3, 6, 5, 14, 11, 6, 6, 14, 12, 17, 22, 19, 16, 3, 19, 3, 11, 8, 5, 14, 4, 9, 11, 20, 8, 8, 5, 5, 8, 3, 5, 5, 12, 9, 2, 13, 6, 17, 7, 7, 9, 8, 12, 18, 10, 7, 3, 6, 4, 10, 6, 3, 11, 7, 7, 1, 4, 8, 11, 17, 15, 5, 13, 19, 11, 7, 5, 11, 6, 8, 6, 4, 4, 13, 8, 18, 5, 13, 24, 6, 17, 5, 8, 3, 12, 8, 2, 6, 22, 2, 17, 19, 5, 2, 7, 28, 5, 3, 11, 6, 6, 15, 42, 1, 5, 24, 17, 33, 35, 30, 4, 14, 10, 2, 4, 42, 8, 11, 11, 33, 2, 1, 6, 9, 4, 2, 4, 3, 8, 23, 13, 50, 14, 26, 293, 20, 24, 30, 10, 8, 11, 20, 18, 16, 16, 31, 21, 51, 5, 26, 21, 29, 14, 4, 6, 26, 33, 35, 6, 5, 11, 9, 29, 11, 5, 16, 30, 7, 17, 22, 24, 21, 15, 17,  ...

# %%
G = nx.from_pandas_edgelist(trips_grouped_count,
                            source='idunplug_station',
                            target='idplug_station',
                            edge_attr=['weight']
                            )
nx.write_gexf(G, 'bicimad.gexf')

# %%
G = nx.from_pandas_edgelist(trips_grouped_count[trips_grouped_count['weight'] > np.percentile(trips_grouped_count['weight'], 99)],
                            source='idunplug_station',
                            target='idplug_station',
                            edge_attr=['weight', 'cost']
                            )

# %%
for n, d in G.degree:
    G.nodes[n]['size'] = d
    G.nodes[n]['title'] = stations[stations['Número'] == n]['Direccion'].reset_index(drop=True).get(0, None)

# %%
for t in G.edges:
    e = G.edges[t]
    e['title'] = 'Cost: ' + str(round(e['cost']/60, 3)) + ' min.'

# %%
print(nx.info(G), '\nDensity: ' + str(round(nx.density(G), 5)))
# Out:
# Name:
# Type: Graph
# Number of nodes: 92
# Number of edges: 212
# Average degree:   4.6087
# Density: 0.05065

# %%
[(n, d, G.nodes[n]['title']) for n, d in sorted(G.degree, key=lambda x: x[1], reverse=True)][:10]
# Out:
# [(149, 21, 'LA HABANA, PASEO, DE, 42'),
#  (175, 19, 'JAIME EL CONQUISTADOR, CALLE, DE, 30'),
#  (163, 19, 'ESPERANZA, PASEO, DE LA, 0,0833333333333333'),
#  (135, 18, 'SAN JUAN DE LA CRUZ, PLAZA, DE, S/N'),
#  (57, 17, 'SANTA CRUZ DE MARCENADO, CALLE, DE, 24'),
#  (129, 14, 'JOSE ABASCAL, CALLE, DE, 33'),
#  (90, 13, 'GOYA, CALLE, DE, 18'),
#  (42, 11, 'SANTA ISABEL, CALLE, DE, 32'),
#  (19, 11, 'PRIM, CALLE, DE, 4'),
#  (132, 11, 'SANTA ENGRACIA, CALLE, DE, 168')]

# %%
betweenness_dict = nx.betweenness_centrality(G) # Run betweenness centrality
eigenvector_dict = nx.eigenvector_centrality(G) # Run eigenvector centrality

# Assign each to an attribute in your network
nx.set_node_attributes(G, betweenness_dict, 'betweenness')
nx.set_node_attributes(G, eigenvector_dict, 'eigenvector')

# %%
[(n, G.degree[n], b, G.nodes[n]['title']) for n, b in sorted(betweenness_dict.items(), key=lambda x: x[1], reverse=True)][:10]
# Out:
# [(19, 11, 0.28774372542507803, 'PRIM, CALLE, DE, 4'),
#  (57, 17, 0.21489806552746704, 'SANTA CRUZ DE MARCENADO, CALLE, DE, 24'),
#  (163, 19, 0.18844217262144433, 'ESPERANZA, PASEO, DE LA, 0,0833333333333333'),
#  (149, 21, 0.18078109940208628, 'LA HABANA, PASEO, DE, 42'),
#  (90, 13, 0.17963208507358477, 'GOYA, CALLE, DE, 18'),
#  (175, 19, 0.11071695309809834, 'JAIME EL CONQUISTADOR, CALLE, DE, 30'),
#  (83, 9, 0.10746118960404677, 'PIO BAROJA, CALLE, DE, 8 B'),
#  (135, 18, 0.1040192687149446, 'SAN JUAN DE LA CRUZ, PLAZA, DE, S/N'),
#  (132, 11, 0.10114493602429507, 'SANTA ENGRACIA, CALLE, DE, 168'),
#  (84, 8, 0.1006356317674999, 'DOCTOR ESQUERDO, CALLE, DEL, 191')]

# %%
nt = Network('1000px', '1000px', notebook=True)
# populates the nodes and edges data structures
nt.from_nx(G)
# nt.toggle_physics(False)
# nt.toggle_stabilization(False)
nt.show('bicimad.html')
# Out:
#         <iframe
#             width="1000px"
#             height="1000px"
#             src="bicimad.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
px.histogram(trips[(trips['idunplug_station'] == 10) & (trips['idplug_station'] == 10)]['travel_time'] / 60, marginal='box')
# Out:
# <div>                            <div id="70aa6a7d-b9ff-4aa2-9f6a-377f2c7410f4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("70aa6a7d-b9ff-4aa2-9f6a-377f2c7410f4")) {                    Plotly.newPlot(                        "70aa6a7d-b9ff-4aa2-9f6a-377f2c7410f4",                        [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "variable=travel_time<br>value=%{x}<br>count=%{y}<extra></extra>", "legendgroup":